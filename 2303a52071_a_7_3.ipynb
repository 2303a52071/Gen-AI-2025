# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52071/Gen-AI-2025/blob/main/2303a52071_a_7_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense,Input
from tensorflow.keras.optimizers import SGD
import pandas as pd #data manipulation

df = pd.read_csv("/content/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame with numerical features
# Select numerical columns for normalization
numerical_cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction']  # Replace with your actual column names

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the scaler on the numerical features and transform them
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Display the normalized DataFrame
df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                  0.234415   50        1
# 1                  0.116567   31        0
# 2                  0.253629   32        1
# 3                  0.038002   21        0
# 4                  0.943638   33        1

# %%
x = df.drop('Outcome', axis=1)
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.507538       0.622951       0.484848  0.212766  0.490313
# 764     0.117647  0.613065       0.573770       0.272727  0.000000  0.548435
# 765     0.294118  0.608040       0.590164       0.232323  0.132388  0.390462
# 766     0.058824  0.633166       0.491803       0.000000  0.000000  0.448584
# 767     0.058824  0.467337       0.573770       0.313131  0.000000  0.453055
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
y = df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adagrad
model = Sequential()
#i/l
model.add(Input(shape=(x_train.shape[1],)))
#h/l
model.add(Dense(12, activation='swish'))
model.add(Dense(25, activation='swish'))
model.add(Dense(15, activation='swish'))
#o/l
model.add(Dense(1))

model.compile(optimizer=Adagrad(), loss='mse', metrics=['accuracy'])
history = model.fit(x_train,y_train,epochs =300,batch_size = 16,validation_split=0.2)
model.summary()
# Out:
# Epoch 1/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6731 - loss: 24.1404 - val_accuracy: 0.5772 - val_loss: 9.6010
# Epoch 2/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6583 - loss: 7.1624 - val_accuracy: 0.5772 - val_loss: 4.1190
# Epoch 3/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6744 - loss: 2.8517 - val_accuracy: 0.5772 - val_loss: 2.0301
# Epoch 4/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6372 - loss: 1.5455 - val_accuracy: 0.5772 - val_loss: 1.1124
# Epoch 5/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6312 - loss: 0.8550 - val_accuracy: 0.5772 - val_loss: 0.6785
# Epoch 6/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6674 - loss: 0.4854 - val_accuracy: 0.5772 - val_loss: 0.4605
# Epoch 7/300
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6893 - loss: 0.3200 - val_accuracy: 0.5772 - val_loss: 0.3492
# Epoch 8/300
# ...

# %%
# prompt: Calculate training and testing accuracy, build confusion matrix, also calculate recall,
# precision and F1-score. using sckit

from sklearn.metrics import confusion_matrix, classification_report

# Predict on the test set
y_pred = model.predict(x_test)

# Convert probabilities to binary predictions (assuming 0.5 as threshold)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculate training accuracy
_, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")

# Calculate testing accuracy
_, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Testing Accuracy: {test_accuracy * 100:.2f}%")


# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:\n", cm)

# Classification Report (includes precision, recall, F1-score)
print(classification_report(y_test, y_pred_binary))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Training Accuracy: 72.15%
# Testing Accuracy: 75.32%
# Confusion Matrix:
#  [[102   0]
#  [ 38  14]]
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84       102
#            1       1.00      0.27      0.42        52
#
#     accuracy                           0.75       154
#    macro avg       0.86      0.63      0.63       154
# weighted avg       0.82      0.75      0.70       154
